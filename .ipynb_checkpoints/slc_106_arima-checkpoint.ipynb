# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
plt.style.use("fivethirtyeight")
import datetime
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller,acf, pacf
import random

plt.rcParams["figure.figsize"] = (20, 8)

# %%
def parser(x):
    return datetime.datetime.strptime(x, '%d/%m/%y')
 
df = pd.read_csv("/home/parth/Downloads/slc_106.csv", parse_dates=[0],squeeze=True, date_parser = parser)
df.head()
# Out:
#         Date  V RY (Volt)  V YB (Volt)  V BR (Volt)  \
# 0 2020-06-16       228.62       240.39       231.59
# 1 2020-06-16       231.36       246.41       233.51
# 2 2020-06-16       228.33       248.58       235.11
# 3 2020-06-16       233.63       242.99       237.39
# 4 2020-06-16       223.87       226.77       216.73
#
#    Cumulative KiloWatt Hrs (kWh)  IR (Amp)  IY (Amp)  IB (Amp)  \
# 0                         5221.1      0.08       0.0      0.00
# 1                         5221.1      0.08       0.0      0.00
# 2                         5221.1      0.08       0.0      0.01
# 3                         5221.1      0.08       0.0      0.00
# 4                         5221.1      0.08       0.0      0.00
#
#    Power (Kilowatt)         Mode  ...  Run Hours (Hrs)  R_Bulb Failure (nos)  \
# 0               0.0  Astro Clock  ...             5.44                   0.0
# 1               0.0  Astro Clock  ...             5.44                   0.0
# 2               0.0  Astro Clock  ...             5.44                   0.0
# 3               0.0  Astro Clock  ...             5.44                   0.0
# 4               0.0  Astro Clock  ...             5.44                   0.0
#
#    Y_Bulb Failure (nos)  B_Bulb Failure (nos)  Feeder     MCB     L-R   Door  \
# 0                   0.0                   0.0     OFF  Normal  Remote  CLOSE
# 1                   0.0                   0.0     OFF  Normal  Remote  CLOSE
# 2                   0.0                   0.0     OFF  Normal  Remote  CLOSE
# 3                   0.0                   0.0     OFF  Normal  Remote  CLOSE
# 4                   0.0                   0.0     OFF  Normal  Remote  CLOSE
#
#   CONTACTOR FEEDBACK ERROR   Power
# 0                   Normal  Normal
# 1                   Normal  Normal
# 2                   Normal  Normal
# 3                   Normal  Normal
# 4                   Normal  Normal
#
# [5 rows x 22 columns]

# %%
df.Feeder.replace(('ON', 'OFF'), (1, 0), inplace=True)
df = df.drop('Power', axis=1)
df.shape
# Out:
# (8185, 21)

# %%
df.tail(20)
# Out:
#            Date  V RY (Volt)  V YB (Volt)  V BR (Volt)  \
# 8165 2019-09-01       214.66       252.79       246.75
# 8166 2019-09-01       218.88       256.46       241.12
# 8167 2019-09-01       216.94       253.80       240.39
# 8168 2019-09-01       222.70       239.22       231.16
# 8169 2019-09-01       221.76       238.97       231.64
# 8170 2019-09-01         0.00         0.00         0.00
# 8171 2019-09-01         0.00         0.00         0.00
# 8172 2019-09-01       231.67       248.98       237.78
# 8173 2019-09-01       241.54       250.32       239.72
# 8174 2019-09-01       242.61       241.87       243.27
# 8175 2019-09-01       230.05       242.27       245.17
# 8176 2019-09-01       234.80       239.89       245.06
# 8177 2019-09-01       236.85       232.45       245.23
# 8178 2019-09-01       232.81       233.56       250.17
# 8179 2019-09-01       231.34       240.00       238.87
# 8180 2019-09-01       230.31       236.23       237.07
# 8181 2019-09-01       231.10       226.88       240.31
# 8182 2019-09-01       226.53       224.05       235.30
# 8183 2019-09-01       225.63       213.03       238.01
# 8184 2019-09-01       209.70       231.13       232.46
#
#       Cumulative KiloWatt Hrs (kWh)  IR (Amp)  IY (Amp)  IB (Amp)  \
# 8165                         4355.3      0.08      0.00      0.00
# 8166                         4355.3      0.08      0.00      0.00
# 8167                         4355.3      0.09      0.00      0.00
# 8168                         4355.3      0.10      0.00      0.01
# 8169                         4355.3      0.10      0.00      0.01
# 8170                            0.0      0.00      0.00      0.00
# 8171                            0.0      0.00      0.00      0.00
# 8172                         4355.3      0.09      0.00      0.00
# 8173                         4355.3      0.09      0.00      0.00
# 8174                         4355.3      0.09      0.00      0.00
# 8175                         4355.3      0.08      0.00      0.00
# 8176                         4355.3      0.09      0.00      0.00
# 8177                         4355.3      6.18     14.99      5.88
# 8178                         4352.8      6.32     14.90      5.76
# 8179                         4348.9      6.34     14.46      6.07
# 8180                         4342.5      6.37     14.71      6.11
# 8181                         4336.2      6.35     15.30      6.02
# 8182                         4329.8      6.48     15.48      6.12
# 8183                         4323.4      6.50     16.51      6.06
# 8184                         4317.0      7.05     14.96      6.18
#
#       Power (Kilowatt)         Mode  ...  Frequncy (Hz)  Run Hours (Hrs)  \
# 8165              0.00  Astro Clock  ...          50.05             5.59
# 8166              0.00  Astro Clock  ...          50.08             5.59
# 8167              0.00  Astro Clock  ...          50.05             5.59
# 8168              0.00  Astro Clock  ...          50.03             5.59
# 8169              0.00  Astro Clock  ...          50.04             5.59
# 8170              0.00  Astro Clock  ...           0.00             0.00
# 8171              0.00  Astro Clock  ...           0.00             0.00
# 8172              0.00  Astro Clock  ...          50.01             5.59
# 8173              0.00  Astro Clock  ...          49.98             5.59
# 8174              0.00  Astro Clock  ...          50.05             5.59
# 8175              0.00  Astro Clock  ...          50.05             5.59
# 8176              0.00  Astro Clock  ...          50.17             5.59
# 8177              6.38  Astro Clock  ...          50.17             5.59
# 8178              6.38  Astro Clock  ...          50.02             5.36
# 8179              6.38  Astro Clock  ...          50.06             4.59
# 8180              6.38  Astro Clock  ...          50.05             3.59
# 8181              6.38  Astro Clock  ...          49.99             2.59
# 8182              6.37  Astro Clock  ...          49.92             1.59
# 8183              6.42  Astro Clock  ...          50.04             0.59
# 8184              6.37  Astro Clock  ...          49.97            11.13
#
#       R_Bulb Failure (nos)  Y_Bulb Failure (nos)  B_Bulb Failure (nos)  \
# 8165                   0.0                   0.0                   NaN
# 8166                   0.0                   0.0                   NaN
# 8167                   0.0                   0.0                   NaN
# 8168                   0.0                   0.0                   NaN
# 8169                   0.0                   0.0                   NaN
# 8170                   0.0                   0.0                   NaN
# 8171                   0.0                   0.0                   NaN
# 8172                   0.0                   0.0                   NaN
# 8173                   0.0                   0.0                   NaN
# 8174                   0.0                   0.0                   NaN
# 8175                   0.0                   0.0                   NaN
# 8176                   0.0                   0.0                   NaN
# 8177                   0.0                   0.0                   NaN
# 8178                   0.0                   0.0                   NaN
# 8179                   0.0                   0.0                   NaN
# 8180                   0.0                   0.0                   NaN
# 8181                   0.0                   0.0                   NaN
# 8182                   0.0                   0.0                   NaN
# 8183                   0.0                   0.0                   NaN
# 8184                   0.0                   0.0                   NaN
#
#       Feeder     MCB     L-R   Door CONTACTOR FEEDBACK ERROR
# 8165     0.0  Normal  Remote  CLOSE                   Normal
# 8166     0.0  Normal  Remote  CLOSE                   Normal
# 8167     0.0  Normal  Remote  CLOSE                   Normal
# 8168     0.0  Normal  Remote  CLOSE                   Normal
# 8169     0.0  Normal  Remote  CLOSE                   Normal
# 8170     0.0  Normal  Remote  CLOSE                   Normal
# 8171     0.0  Normal  Remote  CLOSE                   Normal
# 8172     0.0  Normal  Remote  CLOSE                   Normal
# 8173     0.0  Normal  Remote  CLOSE                   Normal
# 8174     0.0  Normal  Remote  CLOSE                   Normal
# 8175     0.0  Normal  Remote  CLOSE                   Normal
# 8176     0.0  Normal  Remote  CLOSE                   Normal
# 8177     0.0  Normal  Remote  CLOSE                   Normal
# 8178     1.0  Normal  Remote  CLOSE                   Normal
# 8179     1.0  Normal  Remote  CLOSE                   Normal
# 8180     1.0  Normal  Remote  CLOSE                   Normal
# 8181     1.0  Normal  Remote  CLOSE                   Normal
# 8182     1.0  Normal  Remote  CLOSE                   Normal
# 8183     1.0  Normal  Remote  CLOSE                   Normal
# 8184     1.0  Normal  Remote  CLOSE                   Normal
#
# [20 rows x 21 columns]

# %%
df.rename(columns = {'Power (Kilowatt)' : 'Power', 'Run Hours (Hrs)' : 'Burn_hrs'}, inplace=True)

# %%
df.dtypes
# Out:
# Date                             datetime64[ns]
# V RY (Volt)                             float64
# V YB (Volt)                             float64
# V BR (Volt)                             float64
# Cumulative KiloWatt Hrs (kWh)           float64
# IR (Amp)                                float64
# IY (Amp)                                float64
# IB (Amp)                                float64
# Power                                   float64
# Mode                                     object
# Power Factor (PF)                       float64
# Frequncy (Hz)                           float64
# Burn_hrs                                float64
# R_Bulb Failure (nos)                    float64
# Y_Bulb Failure (nos)                    float64
# B_Bulb Failure (nos)                    float64
# Feeder                                  float64
# MCB                                      object
# L-R                                      object
# Door                                     object
# CONTACTOR FEEDBACK ERROR                 object
# dtype: object

# %%
df['Power'].shape
# Out:
# (8185,)

# %%
df['Feeder'].where(df['Feeder'] == 0).count()
# Out:
# 4566

# %%
df['Power'].where(df['Power'] == 0).count()
# Out:
# 4594

# %%
df.drop(df[(df['Power'] != 0) & (df['Feeder'] == 0)].index, inplace = True)

# %%
df.shape
# Out:
# (8164, 21)

# %%
df = df[['Date' , 'Power' , 'Burn_hrs']]
df.dtypes
# Out:
# Date        datetime64[ns]
# Power              float64
# Burn_hrs           float64
# dtype: object

# %%
def rolling_mean_plot(data, window):
    rolling_mean = data['Power'].rolling(window = window).mean()
    rolling_std = data['Power'].rolling(window = window).std()
    plt.figure(figsize=(20,10))
    plt.plot(rolling_mean)
    plt.plot(rolling_std)
    plt.xlabel('Date')
    plt.ylabel('Rolling mean Power in kW')
    plt.grid(True)
    return rolling_mean

# %%
df = df.dropna()
date = []
Power = []
burn_hrs = []
add = 0
counter = 0
x = df.Date[0]
date.append(df.Date[0])
for i in range(df.Date.shape[0]):
    if (df.Power.values[i] == 0):
        continue
    
    if (x != df.Date.values[i]):
        x = df.Date.values[i]
        date.append(df.Date.values[i])
        max_burn_hr = max(burn_hrs)
        add = add/counter
        Power.append(add*max_burn_hr)
        burn_hrs.clear()
        add = 0
        counter = 0
    
    add += df.Power.values[i]
    counter += 1
    burn_hrs.append(df.Burn_hrs.values[i])
    
    if(i == df.Date.shape[0]-1):
        max_burn_hr = max(burn_hrs)
        add = add/counter
        Power.append(add*max_burn_hr)
        break

# %%
Date = np.array(date)
Power = np.array(Power)
date = Date.reshape(-1,1)
Power = Power.reshape(-1,1)
d = np.concatenate((date, Power), axis=1)

# %%
df = pd.DataFrame(d, columns=['Date', 'Power'])
df = df.astype({"Power": float})

# %%
print(df.shape)
df = df[::-1]
df
# Out:
# (281, 2)
#           Date      Power
# 280 2019-09-01  64.850800
# 279 2019-09-02  60.067103
# 278 2019-09-03  71.438706
# 277 2019-09-04  71.417025
# 276 2019-09-05  71.670787
# ..         ...        ...
# 4   2020-06-12  60.934616
# 3   2020-06-13  58.981050
# 2   2020-06-14  52.886895
# 1   2020-06-15  58.859833
# 0   2020-06-16  59.569422
#
# [281 rows x 2 columns]

# %%
print(df['Power'].isnull().values.any())
print(df['Power'].eq(0).any().any())
# Out:
# False
# False

# %%
pd.plotting.autocorrelation_plot(df['Power'])

# %%
# plt.figure(figsize=(100,50))
# plt.plot_date(dat_2.Date, dat_2.Power, linestyle='solid', color='violet')
# plt.gcf().autofmt_xdate()
# plt.tight_layout()
# plt.grid(True)
df1=df.loc[:,['Date','Power']]
df1.set_index('Date',inplace=True)
df1.plot(figsize=(20,10))
plt.legend().set_visible(True)
plt.tight_layout()
sns.despine(top=True)
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Total Power Consumed in kW')

# dat_1.plot()
plt.show()

# %%
ewa=df1.Power.ewm(span=30,adjust=True).mean()
ewa.plot(figsize=(20,10))
plt.grid(True)
plt.legend()
plt.xlabel('Date')
plt.ylabel('Exponential Weighted Mean Power in kW')
ewa
# Out:
# Date
# 2019-09-01    64.850800
# 2019-09-02    62.379223
# 2019-09-03    65.602534
# 2019-09-04    67.204638
# 2019-09-05    68.220795
#                 ...
# 2020-06-12    56.086890
# 2020-06-13    56.273610
# 2020-06-14    56.055112
# 2020-06-15    56.236062
# 2020-06-16    56.451118
# Name: Power, Length: 281, dtype: float64

# %%
rolling_mean_plot(df, 30)
# Out:
# 280          NaN
# 279          NaN
# 278          NaN
# 277          NaN
# 276          NaN
#          ...
# 4      55.336455
# 3      55.507125
# 2      55.481522
# 1      55.656766
# 0      55.854127
# Name: Power, Length: 281, dtype: float64

# %%
df2 = np.log(df1)

# %%
print("Rresuls of Dickey-Fuller Test")
dftest = adfuller(df2['Power'], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags used', 'No. of Observations used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Rresuls of Dickey-Fuller Test
# Test Statistic               -4.110875
# p-value                       0.000929
# #Lags used                    6.000000
# No. of Observations used    274.000000
# Critical Value (1%)          -3.454444
# Critical Value (5%)          -2.872147
# Critical Value (10%)         -2.572422
# dtype: float64

# %%
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
first_diff = df1.Power - df1.Power.shift(1)
first_diff = first_diff.dropna(inplace = False)

# %%
acf_data = acf(first_diff, nlags=40)
pacf_data = pacf(first_diff, nlags=40, method='ols')
# plt.figure(figsize=(20,8))

# ACF DATA PLOT
plt.subplot(2, 1, 1)
plt.title('ACF PLOT')
plt.axhline(y=0, linestyle='--', color='r')
plt.axhline(y=-1.96/np.sqrt(len(df1)), linestyle='--', color='r')
plt.axhline(y=1.96/np.sqrt(len(df1)), linestyle='--', color='r')
plt.plot(acf_data)

# PACF DATA PLOT
plt.subplot(2, 1, 2)
plt.title('PACF PLOT')
plt.axhline(y=0, linestyle='--', color='r')
plt.axhline(y=-1.96/np.sqrt(len(df1)), linestyle='--', color='r')
plt.axhline(y=1.96/np.sqrt(len(df1)), linestyle='--', color='r')
plt.plot(pacf_data)

plt.tight_layout()
plt.grid(True)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
test_stationarity(df2)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0009. The series is likely stationary.
# Test Statistic                  -4.110875
# p-value                          0.000929
# #Lags Used                       6.000000
# Number of Observations Used    274.000000
# Critical Value (1%)             -3.454444
# Critical Value (5%)             -2.872147
# Critical Value (10%)            -2.572422
# dtype: float64

# %%
test_stationarity(df1)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0546. The series is likely non-stationary.
# Test Statistic                  -2.826044
# p-value                          0.054649
# #Lags Used                       2.000000
# Number of Observations Used    278.000000
# Critical Value (1%)             -3.454094
# Critical Value (5%)             -2.871993
# Critical Value (10%)            -2.572340
# dtype: float64

# %%
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df2, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df2, lags=40, ax=ax2)

# %%
X = df1.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(1,0,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast(30)[0]
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
    
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)


# for t in range(10):
#     model = ARIMA(history, order=(5,1,2))
#     model_fit = model.fit(disp=0)
#     output = model_fit.predict()
#     yhat = output[0]
#     predictions.append(yhat)
#     history.append(yhat)
# Out:
# predicted=101.014076, expected=102.190737
# predicted=100.616020, expected=111.908760
# predicted=109.998109, expected=111.142069
# predicted=106.327885, expected=111.036900
# predicted=109.128003, expected=113.376667
# predicted=110.446027, expected=109.433514
# predicted=106.725657, expected=100.303171
# predicted=99.318674, expected=99.860957
# predicted=100.541430, expected=98.353925
# predicted=97.152072, expected=98.914200
# predicted=98.512353, expected=98.408550
# predicted=96.933272, expected=97.446071
# predicted=96.547179, expected=96.847182
# predicted=95.813899, expected=96.363200
# predicted=95.424258, expected=96.119242
# predicted=95.133650, expected=95.412414
# predicted=94.421780, expected=86.041600
# predicted=85.495394, expected=0.104400
# predicted=-0.259685, expected=0.104900
# predicted=30.978604, expected=20.824436
# predicted=24.841473, expected=42.099305
# predicted=47.627208, expected=46.761171
# predicted=45.894696, expected=46.746350
# predicted=49.777182, expected=46.680743
# predicted=49.009302, expected=46.564393
# predicted=49.752958, expected=46.530943
# predicted=49.470211, expected=50.891077
# predicted=53.985546, expected=48.222318
# predicted=49.934435, expected=44.038720
# predicted=47.607060, expected=46.112981
# predicted=49.814899, expected=46.222431
# predicted=48.734594, expected=52.082093
# predicted=55.104305, expected=60.273000
# predicted=61.260761, expected=60.304747
# predicted=60.443170, expected=60.055800
# predicted=61.626342, expected=58.929000
# predicted=60.286466, expected=58.587880
# predicted=60.554150, expected=51.780225
# predicted=53.534818, expected=56.183615
# predicted=59.969007, expected=55.809500
# predicted=56.559439, expected=49.116400
# predicted=51.662163, expected=42.463750
# predicted=46.051998, expected=42.234400
# predicted=46.539127, expected=42.484500
# predicted=45.469029, expected=42.525000
# predicted=45.592873, expected=42.129600
# predicted=44.893647, expected=42.298800
# predicted=45.189710, expected=42.374750
# predicted=45.010353, expected=42.189350
# predicted=44.850480, expected=41.871700
# predicted=44.507164, expected=41.912000
# predicted=44.571684, expected=41.583700
# predicted=44.114825, expected=36.720000
# predicted=39.295322, expected=41.634000
# predicted=45.530580, expected=41.262900
# predicted=42.489035, expected=46.674450
# predicted=49.613349, expected=54.588450
# predicted=55.189240, expected=54.796000
# predicted=54.871157, expected=54.485550
# predicted=55.806919, expected=54.175600
# predicted=55.429292, expected=54.012700
# predicted=55.569088, expected=53.910500
# predicted=55.399109, expected=53.860950
# predicted=55.406408, expected=53.655000
# predicted=55.162262, expected=53.602500
# predicted=55.164175, expected=53.648600
# predicted=55.155710, expected=53.343200
# predicted=54.830893, expected=53.138250
# predicted=54.704527, expected=54.104400
# predicted=55.641208, expected=53.744250
# predicted=54.962164, expected=53.236750
# predicted=54.788886, expected=53.025000
# predicted=54.537290, expected=53.279700
# predicted=54.806654, expected=53.128050
# predicted=54.511648, expected=52.752700
# predicted=54.242941, expected=47.111111
# predicted=48.615757, expected=52.609700
# predicted=55.689931, expected=50.167307
# predicted=50.242995, expected=49.948646
# predicted=52.526971, expected=47.155616
# predicted=48.386411, expected=62.486387
# predicted=65.014232, expected=62.327571
# predicted=59.601101, expected=52.657500
# predicted=54.104427, expected=59.719200
# predicted=62.339032, expected=60.840000
# predicted=60.117827, expected=60.839350
# predicted=61.898502, expected=60.506667
# predicted=60.959508, expected=60.546200
# predicted=61.537806, expected=55.676190
# predicted=56.452383, expected=58.338638
# predicted=60.603120, expected=63.709609
# predicted=63.899418, expected=60.934616
# predicted=60.709061, expected=58.981050
# predicted=60.356572, expected=52.886895
# predicted=54.036939, expected=58.859833
# predicted=61.590603, expected=59.569422
# Test MSE: 95.922

# %%
plt.figure(figsize=(10,7))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
model_fit.plot_predict(1,350)
plt.show()

# %%
X = df2.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
m = np.log(np.array([55.3,60.8,63.2,62.2,62.2,53.4,61.9,54.7,61.2,61.8,62.2,62.1,48.9,61.9,]))

# %%
history = [x for x in train]
predictions = list()

for t in range(len(test)):
    model = ARIMA(history, order=(1,0,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
    
error = mean_squared_error(np.exp(test), np.exp(predictions))
print('Test MSE: %.3f' % error)


for t in range(len(m)):
    model = ARIMA(history, order=(1,0,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    history.append(m[t])
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(m[t])))

# k = np.hstack((test,m))
# plt.figure(figsize=(10,7))
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# predicted=100.806584, expected=102.190737
# predicted=99.879282, expected=111.908760
# predicted=107.874715, expected=111.142069
# predicted=106.263163, expected=111.036900
# predicted=107.650713, expected=113.376667
# predicted=109.474424, expected=109.433514
# predicted=106.325347, expected=100.303171
# predicted=99.418074, expected=99.860957
# predicted=99.385636, expected=98.353925
# predicted=97.035482, expected=98.914200
# predicted=97.522534, expected=98.408550
# predicted=96.653606, expected=97.446071
# predicted=95.951631, expected=96.847182
# predicted=95.406115, expected=96.363200
# predicted=94.937393, expected=96.119242
# predicted=94.682234, expected=95.412414
# predicted=94.037968, expected=86.041600
# predicted=86.241611, expected=0.104400
# predicted=0.110361, expected=0.104900
# predicted=1.617957, expected=20.824436
# predicted=23.978448, expected=42.099305
# predicted=42.595645, expected=46.761171
# predicted=42.983932, expected=46.746350
# predicted=51.003602, expected=46.680743
# predicted=49.070536, expected=46.564393
# predicted=52.842138, expected=46.530943
# predicted=50.933892, expected=50.891077
# predicted=58.394874, expected=48.222318
# predicted=50.382081, expected=44.038720
# predicted=52.333743, expected=46.112981
# predicted=52.679477, expected=46.222431
# predicted=52.523196, expected=52.082093
# predicted=59.283826, expected=60.273000
# predicted=62.715399, expected=60.304747
# predicted=61.224191, expected=60.055800
# predicted=63.156786, expected=58.929000
# predicted=60.922960, expected=58.587880
# predicted=62.692810, expected=51.780225
# predicted=54.196630, expected=56.183615
# predicted=65.728218, expected=55.809500
# predicted=55.492774, expected=49.116400
# predicted=56.327365, expected=42.463750
# predicted=47.436013, expected=42.234400
# predicted=53.202981, expected=42.484500
# predicted=47.688006, expected=42.525000
# predicted=51.697131, expected=42.129600
# predicted=47.390832, expected=42.298800
# predicted=50.785567, expected=42.374750
# predicted=47.691466, expected=42.189350
# predicted=49.824811, expected=41.871700
# predicted=47.422199, expected=41.912000
# predicted=49.243526, expected=41.583700
# predicted=47.119022, expected=36.720000
# predicted=42.953919, expected=41.634000
# predicted=51.746947, expected=41.262900
# predicted=43.822370, expected=46.674450
# predicted=56.999535, expected=54.588450
# predicted=54.068973, expected=54.796000
# predicted=58.218560, expected=54.485550
# predicted=55.361028, expected=54.175600
# predicted=58.106980, expected=54.012700
# predicted=56.013557, expected=53.910500
# predicted=57.933174, expected=53.860950
# predicted=56.411718, expected=53.655000
# predicted=57.573280, expected=53.602500
# predicted=56.567077, expected=53.648600
# predicted=57.474713, expected=53.343200
# predicted=56.383210, expected=53.138250
# predicted=57.040129, expected=54.104400
# predicted=57.442939, expected=53.744250
# predicted=56.776575, expected=53.236750
# predicted=56.785850, expected=53.025000
# predicted=56.475346, expected=53.279700
# predicted=56.920165, expected=53.128050
# predicted=56.338902, expected=52.752700
# predicted=56.370496, expected=47.111111
# predicted=50.236248, expected=52.609700
# predicted=60.996664, expected=50.167307
# predicted=49.455991, expected=49.948646
# predicted=58.569988, expected=47.155616
# predicted=47.758481, expected=62.486387
# predicted=74.471849, expected=62.327571
# predicted=52.311043, expected=52.657500
# predicted=60.577163, expected=59.719200
# predicted=60.284026, expected=60.840000
# predicted=62.221417, expected=60.839350
# predicted=61.094279, expected=60.506667
# predicted=62.075191, expected=60.546200
# predicted=61.506949, expected=55.676190
# predicted=57.171092, expected=58.338638
# predicted=63.240926, expected=63.709609
# predicted=63.380815, expected=60.934616
# predicted=61.085096, expected=58.981050
# predicted=61.118454, expected=52.886895
# predicted=54.680697, expected=58.859833
# predicted=65.925724, expected=59.569422
# Test MSE: 115.623
# predicted=57.071285, expected=55.300000
# predicted=60.016750, expected=60.800000
# predicted=62.811485, expected=63.200000
# predicted=63.173323, expected=62.200000
# predicted=62.387625, expected=62.200000
# predicted=63.312134, expected=53.400000
# predicted=53.883396, expected=61.900000
# predicted=70.488946, expected=54.700000
# predicted=49.972076, expected=61.200000
# predicted=73.947219, expected=61.800000
# predicted=53.978170, expected=62.200000
# predicted=71.107946, expected=62.100000
# predicted=56.569254, expected=48.900000
# predicted=54.262506, expected=61.900000

# %%
m = np.array(m)
m = m.reshape((-1,1))
k = np.vstack((test,m))
plt.figure(figsize=(10,7))
plt.plot(np.exp(k))
plt.plot(np.exp(predictions), color='red')
plt.show()
# model_fit.plot_predict(1,500)
# plt.show()
print(np.exp(predictions[-14:]))
# Out:
# [[57.07128491]
#  [60.01675017]
#  [62.81148459]
#  [63.17332252]
#  [62.38762505]
#  [63.31213376]
#  [53.88339587]
#  [70.48894616]
#  [49.97207598]
#  [73.94721873]
#  [53.97817005]
#  [71.10794571]
#  [56.56925374]
#  [54.26250589]]

# %%
shift = df1 - df1.shift()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df2, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df2, lags=40, ax=ax2)

# %%
df3 = np.sqrt(df1)
shift = df2 - df2.shift()

# %%
test_stationarity(df3)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0073. The series is likely stationary.
# Test Statistic                  -3.528373
# p-value                          0.007288
# #Lags Used                       2.000000
# Number of Observations Used    278.000000
# Critical Value (1%)             -3.454094
# Critical Value (5%)             -2.871993
# Critical Value (10%)            -2.572340
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df2, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df2, lags=40, ax=ax2)

# %%
history = []
X = df2.Power.values
mod = ARIMA(df2, order=(1,0,2))
mod_fit = mod.fit(disp=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
plt.figure(figsize=(20,8))
# fig, ax = plt.subplots()
# mod_fit.plot_predict('2019-09-01','2020-06-16')
mod_fit.plot_predict(1,500)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Power   No. Observations:                  281
# Model:                     ARMA(1, 2)   Log Likelihood                -155.706
# Method:                       css-mle   S.D. of innovations              0.420
# Date:                Mon, 07 Sep 2020   AIC                            321.413
# Time:                        21:01:50   BIC                            339.604
# Sample:                             0   HQIC                           328.709
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           4.1950      0.095     44.356      0.000       4.010       4.380
# ar.L1.Power     0.8639      0.087      9.900      0.000       0.693       1.035
# ma.L1.Power     0.1274      0.121      1.050      0.294      -0.111       0.365
# ma.L2.Power    -0.6059      0.115     -5.289      0.000      -0.830      -0.381
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1575           +0.0000j            1.1575            0.0000
# MA.1           -1.1838           +0.0000j            1.1838            0.5000
# MA.2            1.3941           +0.0000j            1.3941            0.0000
# -----------------------------------------------------------------------------

# %%
(mod_fit.forecast(10)[0])**2
# Out:
# array([16.35637138, 17.02376631, 17.10140815, 17.16862628, 17.22680315,
#        17.27714221, 17.32068998, 17.35835567, 17.39092853, 17.41909329])

# %%
residuals = pd.DataFrame(mod_fit.resid)
residuals
# Out:
#                    0
# Date
# 2019-09-01 -0.022958
# 2019-09-02 -0.084624
# 2019-09-03  0.148416
# 2019-09-04 -0.031840
# 2019-09-05  0.089276
# ...              ...
# 2020-06-12 -0.038335
# 2020-06-13 -0.034250
# 2020-06-14 -0.143961
# 2020-06-15  0.073712
# 2020-06-16 -0.100953
#
# [281 rows x 1 columns]

# %%
residuals.plot()

# %%
residuals.plot(kind='kde')

# %%
residuals.describe()
# Out:
#                 0
# count  281.000000
# mean    -0.000183
# std      0.420736
# min     -6.617432
# 25%     -0.032832
# 50%      0.038792
# 75%      0.085484
# max      0.768845

# %%
# # Import the library 
# from pmdarima import auto_arima 

# model_auto = auto_arima(train, start_p = 0, start_q = 0, 
#                           max_p = 4, max_q = 4, m = 12, 
#                           start_P = 0, seasonal = False, 
#                           d = None, D = 1, trace = True, 
#                           error_action ='ignore',   # we don't want to know if an order does not work 
#                           suppress_warnings = True,  # we don't want convergence warnings 
#                           stepwise = True)           # set to stepwise

# %%
# fit = model_auto.fit(train)
# forecast = fit.predict(n_periods=96)
# plt.plot(np.exp(forecast))
# plt.plot(np.exp(test))

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose
# result = seasonal_decompose(df3, model='additive', period=1)

# %%
# result.plot()
# plt.show()
